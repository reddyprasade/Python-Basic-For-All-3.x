# %% [markdown]
# # Python Operators are used to perform operations on variables and values.
#
# Python divides the operators in the following groups:
#
# 1. Arithmetic operators
# 2. Assignment operators
# 3. Comparison operators
# 4. Logical operators
# 5. Identity operators
# 6. Membership operators
# 7. Bitwise operators

# %% [markdown]
# ![py](img/Arithmetic Operators.JPG)

# %%
from IPython.display import Image
Image(filename='img/Arithmetic Operators.jpg')

# %% [markdown]
# # Python Arithmetic operators

# %%
2 + 3
# Out:
# 5

# %%
x = 2
y = 3
z = x + y
print ("Addition of two numbers:", +z)
# Out:
# Addition of two numbers: 5

# %%
x = 2
y = 3
# z = x + y
print ("Addition of two numbers:", x+y)
# Out:
# Addition of two numbers: 5

# %%
x = "hello"
y = "world"
print("Addition of Two Strings is:", x+y)
# Out:
# Addition of Two Strings is: helloworld

# %%
print("Addition of Two Strings is:", 2+4)
# Out:
# Addition of Two Strings is: 6

# %%
a = int(input())
b = int(input())
c = a + b
print("Addition of two numbers:", +c, a+b)
# Out:
# 12
# 14
# Addition of two numbers: 26 26

# %% [markdown]
# # Sub

# %%
x = 2
y = 10
x-y
# Out:
# -8

# %%
2 -3
# Out:
# -1

# %%
x = -360
y = 225
z = x - y
print(z)
# Out:
# -585

# %%
x = "hello"
y = "World"
z = x - y
print("Sub of two Strings," +z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7512ac235dcb> in <module>
#       1 x = "hello"
#       2 y = "World"
# ----> 3 z = x - y
#       4 print("Sub of two Strings," +z)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# # MUL

# %%
10*20
# Out:
# 200

# %%
a = 20 
b = 30 
c = a*b
print(c)
# Out:
# 600

# %%
a=50 
b = 100
print(a*b)
# Out:
# 5000

# %% [markdown]
# # DIV

# %%
# DIV OF TWO NUMBERS
a =62.9/3 
print(a)
# Out:
# 20.966666666666665

# %%
z = 2.5 
x = 3.5
print(x/z)# because we are get float values as o/p
int(x/z)# int values
# Out:
# 1.4
# 1

# %%
# moduler %
a = 6
b = 7
print(a%b)
# Out:
# 6

# %%
50%2
# Out:
# 0

# %% [markdown]
# # Floar Div

# %%
# Give input is int we will get as int
# If Give input is Float we will get Float

# %%
# float by float 
a =62.9//3.0
print(a) # we are geting float 
# int by float
c =63//3.0
print(c) # float
# int by int 
b = 62//3 
print(b) # we will get as int
# Out:
# 20.0
# 21.0
# 20

# %% [markdown]
# # Exp

# %%
# Exp **
a = 2
b = 2
c = a**b
print(c)
# Out:
# 4

# %%
a = 10.2
b = 2
print(a**b)
# Out:
# 104.03999999999999

# %%
a = 10
b = 2.2
print(a**b)
print(int(a**b))
print(int(a*b))
# Out:
# 158.48931924611142
# 158
# 22

# %% [markdown]
# # Assignment Operators

# %%
# Assignment operators are used to assign values to variables:
from IPython.display import Image
Image(filename='img/Assignment operators1.jpg')

# %%
x = 2
print(x)
x = 2.5
print(x)
x = "hello"
print(x)
# Out:
# 2
# 2.5
# hello

# %%
x = 2
y = 3
x += y
x -= y
x *= y
x /= y
x//=y
x**=y
print(x)
# Out:
# 0.0

# %%
x = 2
y = 3
x-=y
print(x)
# Out:
# -1

# %%
x = 2
y = 3
x *=y
print(x)
# Out:
# 6

# %%
a = 20
b = 3
a//=b
a
# Out:
# 6

# %%
a = 2
b = 3
a**=b
a
# Out:
# 8

# %%
v = 1
v += 3
print(v)
# Out:
# 4

# %%
v -=5
print(v)
# Out:
# -1

# %%
x= 2
x *= 4
print(x)
# Out:
# 8

# %%
x= 2
x /= 4
print(x)
# Out:
# 0.5

# %%
x= 4
x //= 2
print(x)
# Out:
# 2

# %%
x= 2
x **= 4
print(x)
# Out:
# 16

# %%
x= 2
x <<= 4
print(x)
# Out:
# 32

# %%
x= 2
x >>= 4
print(x)
# Out:
# 0

# %%
x= 2
x %= 4
print(x)
# Out:
# 2

# %%
x= 2
x &= 4
print(x)
# Out:
# 0

# %%
x= 2
x |= 4
print(x)
# Out:
# 6

# %%
a= 2
a ^= 4 # x = x^4 
print(a)
# Out:
# 6

# %% [markdown]
# # Python Comparison operators are used to compare two values:

# %%
from IPython.display import Image
Image(filename='img/Comparison operators.jpg')

# %%
# Equal operator is used for comparing x and y values in the variables.
x = 4
y = 4
print(x==y)
# Out:
# True

# %%
# NotEqual operator is used for comparing x and y values in the variables.
x = 4
y = 4
print(x!=y)
# Out:
# False

# %%
# greater Then operator is used for comparing x and y values in the variables if X is Grater then Y output will be Treu or else False.
x = 4
y = 3
print(x>y)
# Out:
# True

# %%
# Less then operator is used for comparing x and y values in the variables.
x = 4
y = 2
print(x<y)
# Out:
# False

# %%
# Lessthen or Equal operator is used for comparing x and y values in the variables.
x = 4
y = 3
print(x<=y)
# Out:
# False

# %%
# Grater then or Equal operator is used for comparing x and y values in the variables.
x = 4
y = 4


print(x>=y)
# Out:
# True

# %%
x = 10
y = 12

# Output: x > y is False
print('x > y  is',x>y)

# Output: x < y is True
print('x < y  is',x<y)

# Output: x == y is False
print('x == y is',x==y)

# Output: x != y is True
print('x != y is',x!=y)

# Output: x >= y is False
print('x >= y is',x>=y)

# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x > y  is False
# x < y  is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# # Logical operators are used to combine conditional statements:

# %%
from IPython.display import Image
Image(filename='img/Logical operators.jpg')

# %%
x = True
y = False

# We are appling logical on  X and y Output: x and y is False
print(x and y)

# We are appling logical on  X and y  Output: x or y is True
print(x or y)

# We are appling logical on  X and y  Output: not x is False
print(not y)
# Out:
# False
# True
# True

# %% [markdown]
# # Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:

# %%
from IPython.display import Image
Image(filename='img/Identity operators.jpg')

# %%
z = eval(input()) # int, float, complex
z
a = input()
a
# Out:
# 12
# 12
# '12'

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
# x3 = [1,2,3]
# y3 = [1,2,3]

# Output: False
print(x1 is not y1)

# Output: True
print(x2 is y2)

# # Output: False
# print(x3 is y2)
# Out:
# False
# True

# %%
from IPython.display import Image
Image(filename='img/Membership operators.jpg')

# %%
x = 'Hello world'
y = [1,2,3,3,4,5,6]

# Output: True
print('H' in x)

# Output: True
print('True' not in x)

# Output: True
print(1 in y)

# Output: False
print('a' in y)
print(x.capitalize(),x.upper(),x.lower(),x.replace("e","a"),x.split(),x.strip(),x.casefold())
print(max(x))
print(min(x))
# Out:
# True
# True
# True
# False
# Hello world HELLO WORLD hello world Hallo world ['Hello', 'world'] Hello world hello world
# w

# %% [markdown]
# # Bitwise operators are used to compare (binary) numbers:

# %%
from IPython.display import Image
Image(filename='img/Bitwise operators.jpg')

# %%
from IPython.display import Image
Image(filename='img/bin to hex.jpg')

# %% [markdown]
# ## from IPython.display import Image
# Image(filename='img/BitConversion.gif')

# %%
from IPython.display import Image
Image(filename='img/Bit to bytes.png')

# %%
a = 6            # 6 = 0110
b = 1            # 1 = 0001 
c = 0            # 0 = 0000

# When we are using AND Bitwise Operation we have to Multiple two values 
Q = a & b        
print ("And Operation in bits", Q)

# WHEN WE ARE PERFORMING | BITWISE OR OPERATION WE HAVE  TO ADD THE TWO VALUES 
c = a | b       
print (c)

# 
c = a ^ b        
print (c)

c = ~a        
print (c)

c =2 << 1       
print (c)

c = a >> 2      
print (c)
# Out:
# And Operation in bits 0
# 7
# 7
# -7
# 4
# 1

# %% [markdown]
# # Operator Precedence
# The precedence of the operators is important to find out since it enables us to know which operator should be evaluated first. The precedence table of the operators in python is given below.

# %%
from IPython.display import Image
Image(filename='img/Operator Predecessor.jpg')

# %%
a = 20
b = 10
c = 15
d = 5
e = 0

e = (a + b) * c / d       #( 30 * 15 ) / 5
print ("Value of (a + b) * c / d is ",  e)

e = ((a + b) * c) / d     # (30 * 15 ) / 5
print ("Value of ((a + b) * c) / d is ",  e)

e = (a + b) * (c / d);    # (30) * (15/5)
print ("Value of (a + b) * (c / d) is ",  e)

e = a + (b * c) / d;      #  20 + (150/5)
print ("Value of a + (b * c) / d is ",  e)
# Out:
# Value of (a + b) * c / d is  90.0
# Value of ((a + b) * c) / d is  90.0
# Value of (a + b) * (c / d) is  90.0
# Value of a + (b * c) / d is  50.0

# %% [markdown]
# 'abs', 'all', 'any', 'ascii', 'bin', 'bool', 'bytearray', 'bytes', 'callable', 'chr', 'classmethod', 'compile', 'complex', 'copyright', 'credits', 'delattr', 'dict', 'dir', 'divmod', 'enumerate', 'eval', 'exec', 'exit', 'filter', 'float', 'format', 'frozenset', 'getattr', 'globals', 'hasattr', 'hash', 'help', 'hex', 'id', 'input', 'int', 'isinstance', 'issubclass', 'iter', 'len', 'license', 'list', 'locals', 'map', 'max', 'memoryview', 'min', 'next', 'object', 'oct', 'open', 'ord', 'pow', 'print', 'property', 'quit', 'range', 'repr', 'reversed', 'round', 'set', 'setattr', 'slice', 'sorted', 'staticmethod', 'str', 'sum', 'super', 'tuple', 'type', 'vars', 'zip'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9d7d3e2f-71d5-43c9-951e-bea362fb428e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
