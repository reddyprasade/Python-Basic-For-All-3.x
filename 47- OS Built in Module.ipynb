# %%
import os

# %%
os.getcwd()
# Out:
# 'E:\\PYTHON PROGRAMS\\Introduction-Programming-Python'

# %%
os.chdir('C:/Users/reddy/OneDrive/Desktop') # we are Change From C to E

# %%
os.getcwd()
# Out:
# 'C:\\Users\\reddy\\OneDrive\\Desktop'

# %%
os.name
# Out:
# 'nt'

# %%
os.times()
# Out:
# nt.times_result(user=1.09375, system=0.3125, children_user=0.0, children_system=0.0, elapsed=0.0)

# %%
os.getcwdb()
# Out:
# C:\Users\reddy\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
#   """Entry point for launching an IPython kernel.
# b'C:\\Users\\reddy\\OneDrive\\Desktop'

# %%
path = "C:/Users/reddy/OneDrive/Desktop/File"

# %%
os.rmdir(path)

# %%
os.path
# Out:
# <module 'ntpath' from 'c:\\users\\reddy\\appdata\\local\\programs\\python\\python36\\lib\\ntpath.py'>

# %%
os.pardir
# Out:
# '..'

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
#       - os.altsep is the alternate pathname separator (None or '/')
#       - os.pathsep is the component separator used in $PATH etc
#       - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#       - os.defpath is the default search path for executables
#       - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# ...
