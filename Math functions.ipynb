# %%
import math
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(...)
#         atanh(x)
#
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(...)
#         ceil(x)
#
# ...

# %%
x=2
print(math.sin(x))
# Out:
# 0.9092974268256817

# %%
print(math.cos(x))
# Out:
# -0.4161468365471424

# %%
print(math.tan(x))
# Out:
# -2.185039863261519

# %%
print(math.sinh(x))
# Out:
# 3.6268604078470186

# %%
print(math.cosh(x))
# Out:
# 3.7621956910836314

# %%
print(math.tanh(x))
# Out:
# 0.9640275800758169

# %%
print(math.floor(2.5))
# Out:
# 2

# %%
print(math.ceil(2.5))
# Out:
# 3

# %%
import math
print(math.asinh(x))
# Out:
# 1.4436354751788103

# %%
print(math.acosh(x))
# Out:
# 1.3169578969248166

# %%
print(math.atanh(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ca706cfc30fa> in <module>
# ----> 1 print(math.atanh(x))
#
# ValueError: math domain error

# %%
print(math.gcd(2,4))
# Out:
# 2

# %%
print(math.lcm(2,4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-9cf63c71934c> in <module>
# ----> 1 print(math.lcm(2,4))
#
# AttributeError: module 'math' has no attribute 'lcm'

# %%
print(math.degrees(30))
# Out:
# 1718.8733853924696

# %%
r=2
print(math.pi*r*r)
# Out:
# 12.566370614359172

# %%
x=2
y=4
print(math.hypot(x,y))
# Out:
# 4.47213595499958
